# %%
#Multiply function
def multiply(a, b):
    return a * b
#Inputs for user's choice
a=int(input('first number'))
b=int(input('second number'))
#Print the final result
print('the multiplication of  ', a, 'and', b ,'is' ,multiply(a,b))
# Out:
# the multiplication of   5 and 5 is 25

# %% [markdown]
# This code multiples two different numbers of the users input and prints the result back
